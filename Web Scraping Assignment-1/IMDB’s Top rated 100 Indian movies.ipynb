# %%
import requests
from bs4 import *

# %%
page=requests.get("https://www.imdb.com/india/top-rated-indian-movies/")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %%
data=soup.findAll('td', class_ = 'titleColumn')

# %%
movie_name=[]
year_of_release=[]
rating=[]
for i in data:
    name = i.a.text
    movie_name.append(name)
    
    yor = i.find('span', class_='secondaryInfo').text
    year_of_release.append(yor)
    
year_of_release
movie_name
# rate=soup.findAll('td', class_ = "")
# rating.append(rate)
# rating
# Out:
# ['Sardar Udham',
#  'Nayakan',
#  'Anbe Sivam',
#  'Pariyerum Perumal',
#  'C/o Kancharapalem',
#  'Manichitrathazhu',
#  'Golmaal',
#  'Kireedam',
#  'Apur Sansar',
#  'Natsamrat',
#  '96',
#  'Thevar Magan',
#  'Kumbalangi Nights',
#  'Black Friday',
#  'Pather Panchali',
#  'Soorarai Pottru',
#  '#Home',
#  'Visaaranai',
#  '3 Idiots',
#  'Jersey',
#  'Taare Zameen Par',
#  'Asuran',
#  'Thalapathi',
#  'Drishyam 2',
#  'Kaithi',
#  'Sarpatta Parambarai',
#  'Dangal',
#  'Devasuram',
#  'Aparajito',
#  'Jaane Bhi Do Yaaro',
#  'Pyaasa',
#  'Peranbu',
#  'Vada Chennai',
#  'Ratsasan',
#  'Guide',
#  'Thani Oruvan',
#  'Kannathil Muthamittal',
#  'Spadikam',
#  'Agent Sai Srinivasa Athreya',
#  'Iruvar',
#  'Chupke Chupke',
#  'Super Deluxe',
#  'Mahanati',
#  'Aruvi',
#  'Khosla Ka Ghosla!',
#  'Pudhu Pettai',
#  'Drishyam',
#  'Tumbbad',
#  'Anniyan',
#  'Premam',
#  'Mudhalvan',
#  'Vikram Vedha',
#  'Kaakkaa Muttai',
#  'Bangalore Days',
#  'Satya',
#  'Angoor',
#  'Papanasam',
# ...
